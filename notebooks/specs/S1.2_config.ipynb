# %% [markdown]
# # S1.2 — Environment Configuration
#
# Interactive verification that `src/config.py` works correctly.
# Tests: Pydantic settings, env_prefix, URL properties, get_settings() caching.

# %%
import sys
from pathlib import Path

# Add project root to Python path
project_root = str(Path.cwd().parent.parent)
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(f"Project root: {project_root}")
# Out:
# Project root: /Users/nishantgaurav/Project/PaperAlchemy

# %%
from src.config import (
    Settings,
    PostgresSettings,
    OpenSearchSettings,
    OllamaSettings,
    GeminiSettings,
    RedisSettings,
    JinaSettings,
    RerankerSettings,
    LangfuseSettings,
    ArxivSettings,
    ChunkingSettings,
    AppSettings,
    get_settings,
)

print("All settings classes imported successfully!")
# Out:
# All settings classes imported successfully!

# %%
# Root settings composition
s = Settings()
print(f"Sub-settings count: {len([f for f in s.model_fields])}")
print(f"Postgres URL: {s.postgres.url}")
print(f"Postgres sync URL: {s.postgres.sync_url}")
print(f"Ollama URL: {s.ollama.url}")
print(f"Redis URL: {s.redis.url}")
print(f"Gemini model: {s.gemini.model}")
print(f"Reranker model: {s.reranker.model}")
print(f"Jina dimensions: {s.jina.dimensions}")
# Out:
# Sub-settings count: 11
# Postgres URL: postgresql+asyncpg://paperalchemy:paperalchemy_secret@localhost:5433/paperalchemy
# Postgres sync URL: postgresql://paperalchemy:paperalchemy_secret@localhost:5433/paperalchemy
# Ollama URL: http://localhost:11434
# Redis URL: redis://localhost:6380/0
# Gemini model: gemini-2.0-flash
# Reranker model: cross-encoder/ms-marco-MiniLM-L-12-v2
# Jina dimensions: 1024
# /var/folders/09/369xpjkj0bx605z54hlxdxv80000gn/T/ipykernel_8400/2553331657.py:3: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   print(f"Sub-settings count: {len([f for f in s.model_fields])}")

# %%
# get_settings() caching
get_settings.cache_clear()
s1 = get_settings()
s2 = get_settings()
print(f"Same instance: {s1 is s2}")
assert s1 is s2, "get_settings() should return cached instance"
print("Caching works!")
# Out:
# Same instance: True
# Caching works!

# %%
# Verify all 11 sub-settings are present
expected = [
    "postgres", "opensearch", "ollama", "gemini", "redis",
    "jina", "reranker", "langfuse", "arxiv", "chunking", "app",
]
for name in expected:
    assert hasattr(s, name), f"Missing sub-setting: {name}"
    print(f"  {name}: OK")
print(f"\nAll {len(expected)} sub-settings verified!")
# Out:
#   postgres: OK
#   opensearch: OK
#   ollama: OK
#   gemini: OK
#   redis: OK
#   jina: OK
#   reranker: OK
#   langfuse: OK
#   arxiv: OK
#   chunking: OK
#   app: OK
#
# All 11 sub-settings verified!
